# %% [markdown]
# # Hierarchical Multiclass and Multilabel Text Classification for Crime Report: A Traditional Machine Learning Approach

# %% [markdown]
# ## Dataset Analysis

# %%
import pandas as pd

# %%
data = pd.read_csv("./Datasets/01_OriginalDataset.csv")
data.shape
# Out:
# (6533919, 2)

# %%
data['DINAMICA_'].isna().sum()
# Out:
# 17458

# %%
data = data.dropna()
data['DINAMICA_'].isna().sum()
# Out:
# 0

# %%
len(data[data['DINAMICA_'] == "."])
# Out:
# 632

# %%
data = data.drop(data[data['DINAMICA_'] == "."].index)
len(data[data['DINAMICA_'] == "."])
# Out:
# 0

# %%
data.shape
# Out:
# (6174717, 2)

# %% [markdown]
# ## Table Data Analysis

# %%
len(data['TIPO_DELITO'].unique())
# Out:
# 1169

# %%
data['TIPO_DELITO'].value_counts()
# Out:
# TIPO_DELITO
# Estelionato (outros)                                                                              535684
# Roubo a Transeunte                                                                                396744
# Ameaça                                                                                            374633
# Furto outros                                                                                      355123
# Fato Atípico                                                                                      278940
#                                                                                                    ...
# Omissão de Comunicação                                                                                 1
# Extorsão Mediante Sequestro Qualificada - Tentativa (Art. 159 §1º c/c Art. 14, II do CP)               1
# Crime de Genocídio                                                                                     1
# Emprego de Processo Proibido ou de Substância não Permitida com Resultado Lesão Corporal Grave         1
# Participação em Competição não Autorizada com Lesão Corporal Grave                                     1
# Name: count, Length: 1169, dtype: int64

# %%
quantidades = data['TIPO_DELITO'].value_counts().to_frame("Quantidade").reset_index()
quantidades['Acumulativo'] = quantidades['Quantidade'].cumsum()
quantidades['Percentual Acumulado'] = 100*quantidades['Acumulativo']/quantidades['Quantidade'].sum()
quantidades.head(80)
# Out:
#                                           TIPO_DELITO  Quantidade  \
# 0                                Estelionato (outros)      535684
# 1                                  Roubo a Transeunte      396744
# 2                                              Ameaça      374633
# 3                                        Furto outros      355123
# 4                                        Fato Atípico      278940
# ..                                                ...         ...
# 75                                        Maus-Tratos        9541
# 76  Lesão Corporal Provocada por Projétil de Arma ...        9524
# 77                Crime de Perseguição (Art 147-A CP)        9519
# 78  Sanções Penais e Administrativas ao Meio Ambiente        9352
# 79       Porte Ilegal de Arma de Fogo de Uso Restrito        9344
#
#     Acumulativo  Percentual Acumulado
# 0        535684              8.675442
# 1        932428             15.100741
# 2       1307061             21.167950
# 3       1662184             26.919193
# 4       1941124             31.436647
# ..          ...                   ...
# 75      5498302             89.045409
# 76      5507826             89.199651
# 77      5517345             89.353812
# 78      5526697             89.505268
# 79      5536041             89.656595
#
# [80 rows x 4 columns]

# %%
quantidades_90_porcento = quantidades.head(80)
quantidades_90_porcento.tail(10)
# Out:
#                                           TIPO_DELITO  Quantidade  \
# 70  Apreensão de Adolescente Infrator (Artigo 104 ...       10696
# 71     Roubo no Interior de Estabelecimento Comercial       10298
# 72                                            Estupro        9992
# 73             Lei de Drogas (Outros) (Lei 11.343/06)        9918
# 74  Falta de Habilitação, Proibição Dirigir Veícul...        9781
# 75                                        Maus-Tratos        9541
# 76  Lesão Corporal Provocada por Projétil de Arma ...        9524
# 77                Crime de Perseguição (Art 147-A CP)        9519
# 78  Sanções Penais e Administrativas ao Meio Ambiente        9352
# 79       Porte Ilegal de Arma de Fogo de Uso Restrito        9344
#
#     Acumulativo  Percentual Acumulado
# 70      5448772             88.243267
# 71      5459070             88.410044
# 72      5469062             88.571865
# 73      5478980             88.732488
# 74      5488761             88.890892
# 75      5498302             89.045409
# 76      5507826             89.199651
# 77      5517345             89.353812
# 78      5526697             89.505268
# 79      5536041             89.656595

# %%
delitos = list(quantidades_90_porcento['TIPO_DELITO'])
delitos
# Out:
# ['Estelionato (outros)',
#  'Roubo a Transeunte',
#  'Ameaça',
#  'Furto outros',
#  'Fato Atípico',
#  'Roubo de Veículo',
#  'Lesão Corporal (outros)',
#  'Injúria (outros)',
#  'Medida Assecuratória de Direito Futuro',
#  'Roubo outros',
#  'Furto de Telefone Celular',
#  'Roubo de Telefone Celular',
#  'Recuperação de Veículo Roubado',
#  'Lesão Corporal Provocada por Socos, Tapas e Pontapés',
#  'Furto a Transeunte',
#  'Extravio de Documento',
#  'Lesão Corporal Culposa (outros) (Lei 9503/97)',
#  'Furto de Veículo',
#  'Tráfico de Drogas (Lei 11.343/06)',
#  'Porte de Droga para Consumo Próprio (Lei 11.343/06)',
#  'Roubo no Interior de Coletivo',
#  'Cumprimento de Mandado de Prisão',
#  'Furto no Interior de Residência',
#  'Vias de Fato',
#  'Furto no Interior de Estabelecimento Comercial',
#  'Apreensão (outros)',
#  'Furto no Interior de Coletivo',
#  'Furto a Estabelecimento Comercial',
#  'Roubo de Veículo - Moto',
#  'Extravio de Celular',
#  'Furto no Interior de Veículo',
#  'Associação para Tráfico de Droga (Lei 11.343/06)',
#  'Dano (outros)',
#  'Roubo no Interior de Veículo',
#  'Furto de Veículo - Moto',
#  'Roubo de Carga',
#  'Difamação',
#  'Remoção para Verificação de Óbito',
#  'Desaparecimento outros',
#  'Receptação',
#  'Calúnia',
#  'Encontro de Desaparecido',
#  'Estelionato (outros) - Tentativa',
#  'Lesão Corporal Culposa Provocada por Colisão de Veículo',
#  'Recuperação de Veículo Furtado',
#  'Adulteração de Sinal Identificador de Veículo Automotor',
#  'Violação de Domicílio',
#  'Estupro de Vulnerável',
#  'Homicídio Provocado por Projétil de Arma de Fogo',
#  'Morte sem Assistência Médica',
#  'Extravio de Placa de Veículo',
#  'Furto de Bicicleta',
#  'Descumprimento de Medidas Protetivas de Urgência',
#  'Roubo a Estabelecimento Comercial',
#  'Perturbação da Tranquilidade',
#  'Estelionato com Emprego de Cartão de Crédito',
#  'Desacato',
#  'Extorsão (outros)',
#  'Apropriação Indébita (outros)',
#  'Resistência',
#  'Furto de Placa de Veículo',
#  'Apreensão de Substância Entorpecente',
#  'Lesão Corporal Culposa Provocada por Atropelamento',
#  'Desobediência',
#  'Homicídio Provocado por Projétil de Arma de Fogo - Tentativa',
#  'Apreensão de Veículo',
#  'Resistência qualificada',
#  'Exercício Arbitrário das Próprias Razões',
#  'Proveniente de Prisão Preventiva da Unidade Policial',
#  'Injúria por preconceito',
#  'Apreensão de Adolescente Infrator (Artigo 104 e 107 da Lei 8.069/90)',
#  'Roubo no Interior de Estabelecimento Comercial',
#  'Estupro',
#  'Lei de Drogas (Outros) (Lei 11.343/06)',
#  'Falta de Habilitação, Proibição Dirigir Veículo Automotor',
#  'Maus-Tratos',
#  'Lesão Corporal Provocada por Projétil de Arma de Fogo',
#  'Crime de Perseguição (Art 147-A CP)',
#  'Sanções Penais e Administrativas ao Meio Ambiente',
#  'Porte Ilegal de Arma de Fogo de Uso Restrito']

# %%
filtered_data = data[data['TIPO_DELITO'].isin(delitos)]
filtered_data.shape
# Out:
# (5536041, 2)

# %%
filtered_data = filtered_data.rename(columns={"DINAMICA_": "DINAMICA", "TIPO_DELITO": "N3"})
len(filtered_data['N3'].unique())
# Out:
# 80

# %% [markdown]
# ## Stratified Sample

# %%
from sklearn.model_selection import train_test_split

# %%
X = filtered_data.drop(columns=['N3'], axis=1)
y = filtered_data['N3']

SEED = 12345
df_X_train, df_X_test, df_y_train, df_y_test = train_test_split(X, y, test_size=0.05, stratify=y, random_state=SEED)

# %%
train_data = df_X_train
train_data['N3'] = df_y_train
train_data.shape
# Out:
# (5259238, 2)

# %%
test_data = df_X_test
test_data['N3'] = df_y_test
test_data.shape
# Out:
# (276803, 2)

# %%
test_data.to_csv(f"./Datasets/02_NeverSeenBefore.csv", index=False)
train_data.to_csv(f"./Datasets/03_TrainDataset.csv", index=False)

# %% [markdown]
# ## Classification Tree Construction

# %%
domain_hierarchy = pd.read_csv('./Datasets/04_DomainHierarchy.csv')
domain_hierarchy
# Out:
#                                                    N1  \
# 0                           Crimes Contra Propriedade
# 1                           Crimes Contra Propriedade
# 2                           Crimes Contra Propriedade
# 3                           Crimes Contra Propriedade
# 4                           Crimes Contra Propriedade
# ..                                                ...
# 75             Resistência, Desacato ou Desobediência
# 76  Violação ou Perturbação ou Dano ou Exercício A...
# 77  Violação ou Perturbação ou Dano ou Exercício A...
# 78  Violação ou Perturbação ou Dano ou Exercício A...
# 79  Violação ou Perturbação ou Dano ou Exercício A...
#
#                                           N2  \
# 0                                Estelionato
# 1                                Estelionato
# 2                                Estelionato
# 3                                      Roubo
# 4                                      Roubo
# ..                                       ...
# 75                   Resistência qualificada
# 76                     Violação de Domicílio
# 77              Perturbação da Tranquilidade
# 78  Exercício Arbitrário das Próprias Razões
# 79                             Dano (outros)
#
#                                               N3
# 0                           Estelionato (outros)
# 1               Estelionato (outros) - Tentativa
# 2   Estelionato com Emprego de Cartão de Crédito
# 3                             Roubo a Transeunte
# 4                               Roubo de Veículo
# ..                                           ...
# 75                       Resistência qualificada
# 76                         Violação de Domicílio
# 77                  Perturbação da Tranquilidade
# 78      Exercício Arbitrário das Próprias Razões
# 79                                 Dano (outros)
#
# [80 rows x 3 columns]

# %%
augmented = pd.merge(train_data, domain_hierarchy, on='N3', how='left')
augmented = augmented[['DINAMICA', 'N1', 'N2', 'N3']].reset_index().drop(columns="index")
augmented
# Out:
#                                                   DINAMICA  \
# 0        O presente procedimento, que, em tese, trata d...
# 1        Trata-se de cumprimento de mandado de prisão n...
# 2        CONSTA NA BASE DE ÍNDICE NACIONAL A OCORRÊNCIA...
# 3        O comunicante, ALEXANDRE MUNIZ DA SILVA, notic...
# 4        Relata o comunicante, SGT/PM MARCOS ALBERTO DE...
# ...                                                    ...
# 5259233  Erick Marcelo Avelino Batista , informa que en...
# 5259234  WALACE COSTA DA SILVA - Rep. Legal de MANOELA ...
# 5259235  ÁREA DA 16ª DP -- BARRA\r\n\r\n\r\nESTAVA DENT...
# 5259236  A declarante comparece  hoje dia 05/05/2020 pa...
# 5259237  Dominique Nunes de Lima Vieira , informa que e...
#
#                                                         N1  \
# 0                                Crimes Contra Propriedade
# 1        Recuperação de Veículo ou Atos Administrativos...
# 2        Recuperação de Veículo ou Atos Administrativos...
# 3                                     Crimes Contra Pessoa
# 4                                     Crimes Contra Pessoa
# ...                                                    ...
# 5259233                          Crimes Contra Propriedade
# 5259234                               Crimes Contra Pessoa
# 5259235                          Crimes Contra Propriedade
# 5259236                               Crimes Contra Pessoa
# 5259237                          Crimes Contra Propriedade
#
#                                                         N2  \
# 0                                              Estelionato
# 1                                     Atos Administrativos
# 2                                   Recuperação de Veículo
# 3                                           Lesão Corporal
# 4        Ameaça ou Injúria ou Perseguição ou Dano ou Ex...
# ...                                                    ...
# 5259233                                        Estelionato
# 5259234                                     Lesão Corporal
# 5259235                                              Furto
# 5259236  Ameaça ou Injúria ou Perseguição ou Dano ou Ex...
# 5259237                                              Furto
#
#                                                         N3
# 0                                     Estelionato (outros)
# 1                         Cumprimento de Mandado de Prisão
# 2                           Recuperação de Veículo Roubado
# 3                                  Lesão Corporal (outros)
# 4                                                   Ameaça
# ...                                                    ...
# 5259233                               Estelionato (outros)
# 5259234  Lesão Corporal Provocada por Socos, Tapas e Po...
# 5259235                      Furto no Interior de Coletivo
# 5259236                                   Injúria (outros)
# 5259237                                       Furto outros
#
# [5259238 rows x 4 columns]

# %%
augmented.to_csv(f"./Datasets/05_AugmentedDataset.csv", index=False)

# %% [markdown]
# ## Classification Tree Imbalance Analysis

# %%
def resume(data):
    balance = data.value_counts().to_frame('Quantidade').reset_index()
    balance['Acumulativo'] = balance['Quantidade'].cumsum()
    balance['Percentual Acumulado'] = 100*balance['Acumulativo']/balance['Quantidade'].sum()
    balance['Percentual Absoluto'] = 100*balance['Quantidade']/balance['Quantidade'].sum()
    
    return balance

# %%
def n_resume(data, nivel1, nivel2):
    resumes = []
    
    for label in data[nivel1].unique():
        current = resume(data[data[nivel1] == label][nivel2])
        if len(current) > 1:
            resumes.append(current)

    return resumes

# %%
n1_balance = resume(augmented['N1'])
n1_balance
# Out:
#                                                   N1  Quantidade  Acumulativo  \
# 0                          Crimes Contra Propriedade      139221       139221
# 1                               Crimes Contra Pessoa       65057       204278
# 2  Recuperação de Veículo ou Atos Administrativos...       52092       256370
# 3  Relacionados a Drogas, Entorpecentes e Porte d...       10807       267177
# 4  Violação ou Perturbação ou Dano ou Exercício A...        4649       271826
# 5             Resistência, Desacato ou Desobediência        2800       274626
# 6                Crimes de Trânsito ou Meio Ambiente        2177       276803
#
#    Percentual Acumulado  Percentual Absoluto
# 0             50.296059            50.296059
# 1             73.799056            23.502997
# 2             92.618216            18.819160
# 3             96.522437             3.904221
# 4             98.201970             1.679534
# 5             99.213520             1.011550
# 6            100.000000             0.786480

# %%
for dataset in n_resume(augmented, 'N1', 'N2'):
    display(dataset)
# Out:
#                               N2  Quantidade  Acumulativo  \
# 0                          Roubo       55910        55910
# 1                          Furto       52016       107926
# 2                    Estelionato       28979       136905
# 3                     Receptação        1532       138437
# 4  Apropriação Indébita (outros)         784       139221
#
#    Percentual Acumulado  Percentual Absoluto
# 0             40.159171            40.159171
# 1             77.521351            37.362180
# 2             98.336458            20.815107
# 3             99.436867             1.100409
# 4            100.000000             0.563133
#                                                   N2  Quantidade  Acumulativo  \
# 0                  Tráfico de Drogas (Lei 11.343/06)        3649         3649
# 1  Porte de Droga para Consumo Próprio (Lei 11.34...        3416         7065
# 2   Associação para Tráfico de Droga (Lei 11.343/06)        2068         9133
# 3               Apreensão de Substância Entorpecente         711         9844
# 4             Lei de Drogas (Outros) (Lei 11.343/06)         496        10340
# 5       Porte Ilegal de Arma de Fogo de Uso Restrito         467        10807
#
#    Percentual Acumulado  Percentual Absoluto
# 0             33.765152            33.765152
# 1             65.374294            31.609142
# 2             84.510040            19.135745
# 3             91.089109             6.579069
# 4             95.678727             4.589618
# 5            100.000000             4.321273
#                                                   N2  Quantidade  Acumulativo  \
# 0  Ameaça ou Injúria ou Perseguição ou Dano ou Ex...       34195        34195
# 1                                     Lesão Corporal       26712        60907
# 2                                          Homicídio        1621        62528
# 3                                            Estupro        1609        64137
# 4   Descumprimento de Medidas Protetivas de Urgência         920        65057
#
#    Percentual Acumulado  Percentual Absoluto
# 0             52.561600            52.561600
# 1             93.620979            41.059379
# 2             96.112640             2.491661
# 3             98.585855             2.473216
# 4            100.000000             1.414145
#                                          N2  Quantidade  Acumulativo  \
# 0                             Dano (outros)        1982         1982
# 1                     Violação de Domicílio        1206         3188
# 2              Perturbação da Tranquilidade         906         4094
# 3  Exercício Arbitrário das Próprias Razões         555         4649
#
#    Percentual Acumulado  Percentual Absoluto
# 0             42.632824            42.632824
# 1             68.573887            25.941063
# 2             88.061949            19.488062
# 3            100.000000            11.938051
#                              N2  Quantidade  Acumulativo  \
# 0  Registro de Um Acontecimento       26911        26911
# 1          Atos Administrativos       17646        44557
# 2        Recuperação de Veículo        7535        52092
#
#    Percentual Acumulado  Percentual Absoluto
# 0             51.660524            51.660524
# 1             85.535207            33.874683
# 2            100.000000            14.464793
#                         N2  Quantidade  Acumulativo  Percentual Acumulado  \
# 0                 Desacato         789          789             28.178571
# 1              Resistência         757         1546             55.214286
# 2            Desobediência         661         2207             78.821429
# 3  Resistência qualificada         593         2800            100.000000
#
#    Percentual Absoluto
# 0            28.178571
# 1            27.035714
# 2            23.607143
# 3            21.178571
#                                                   N2  Quantidade  Acumulativo  \
# 0  Adulteração de Sinal Identificador de Veículo ...        1220         1220
# 1  Falta de Habilitação, Proibição Dirigir Veícul...         489         1709
# 2  Sanções Penais e Administrativas ao Meio Ambiente         468         2177
#
#    Percentual Acumulado  Percentual Absoluto
# 0             56.040423            56.040423
# 1             78.502526            22.462104
# 2            100.000000            21.497474

# %%
for dataset in n_resume(augmented, 'N2', 'N3'):
    display(dataset)
# Out:
#                                                N3  Quantidade  Acumulativo  \
# 0                              Roubo a Transeunte       19837        19837
# 1                                Roubo de Veículo       10600        30437
# 2                                    Roubo outros        8048        38485
# 3                       Roubo de Telefone Celular        6849        45334
# 4                   Roubo no Interior de Coletivo        3392        48726
# 5                         Roubo de Veículo - Moto        2123        50849
# 6                    Roubo no Interior de Veículo        1888        52737
# 7                                  Roubo de Carga        1747        54484
# 8               Roubo a Estabelecimento Comercial         911        55395
# 9  Roubo no Interior de Estabelecimento Comercial         515        55910
#
#    Percentual Acumulado  Percentual Absoluto
# 0             35.480236            35.480236
# 1             54.439277            18.959041
# 2             68.833840            14.394563
# 3             81.083885            12.250045
# 4             87.150778             6.066893
# 5             90.947952             3.797174
# 6             94.324808             3.376856
# 7             97.449472             3.124665
# 8             99.078877             1.629404
# 9            100.000000             0.921123
#                                                 N3  Quantidade  Acumulativo  \
# 0                                     Furto outros       17756        17756
# 1                        Furto de Telefone Celular        7849        25605
# 2                               Furto a Transeunte        6019        31624
# 3                                 Furto de Veículo        3989        35613
# 4                  Furto no Interior de Residência        3344        38957
# 5   Furto no Interior de Estabelecimento Comercial        2783        41740
# 6                    Furto no Interior de Coletivo        2526        44266
# 7                Furto a Estabelecimento Comercial        2244        46510
# 8                     Furto no Interior de Veículo        2091        48601
# 9                          Furto de Veículo - Moto        1760        50361
# 10                              Furto de Bicicleta         921        51282
# 11                       Furto de Placa de Veículo         734        52016
#
#     Percentual Acumulado  Percentual Absoluto
# 0              34.135651            34.135651
# 1              49.225238            15.089588
# 2              60.796678            11.571440
# 3              68.465472             7.668794
# 4              74.894263             6.428791
# 5              80.244540             5.350277
# 6              85.100738             4.856198
# 7              89.414795             4.314057
# 8              93.434712             4.019917
# 9              96.818287             3.383574
# 10             98.588896             1.770609
# 11            100.000000             1.411104
#                                                   N3  Quantidade  Acumulativo  \
# 0                            Lesão Corporal (outros)       10560        10560
# 1  Lesão Corporal Provocada por Socos, Tapas e Po...        6224        16784
# 2      Lesão Corporal Culposa (outros) (Lei 9503/97)        4274        21058
# 3                                       Vias de Fato        3130        24188
# 4  Lesão Corporal Culposa Provocada por Colisão d...        1337        25525
# 5  Lesão Corporal Culposa Provocada por Atropelam...         711        26236
# 6  Lesão Corporal Provocada por Projétil de Arma ...         476        26712
#
#    Percentual Acumulado  Percentual Absoluto
# 0             39.532794            39.532794
# 1             62.833184            23.300389
# 2             78.833483            16.000299
# 3             90.551063            11.717580
# 4             95.556304             5.005241
# 5             98.218029             2.661725
# 6            100.000000             1.781971
#                                              N3  Quantidade  Acumulativo  \
# 0                          Estelionato (outros)       26784        26784
# 1              Estelionato (outros) - Tentativa        1355        28139
# 2  Estelionato com Emprego de Cartão de Crédito         840        28979
#
#    Percentual Acumulado  Percentual Absoluto
# 0             92.425550            92.425550
# 1             97.101349             4.675800
# 2            100.000000             2.898651
#                                     N3  Quantidade  Acumulativo  \
# 0                               Ameaça       18732        18732
# 1                     Injúria (outros)       10027        28759
# 2                            Difamação        1712        30471
# 3                              Calúnia        1447        31918
# 4                    Extorsão (outros)         787        32705
# 5              Injúria por preconceito         537        33242
# 6                          Maus-Tratos         477        33719
# 7  Crime de Perseguição (Art 147-A CP)         476        34195
#
#    Percentual Acumulado  Percentual Absoluto
# 0             54.779939            54.779939
# 1             84.102939            29.323000
# 2             89.109519             5.006580
# 3             93.341132             4.231613
# 4             95.642638             2.301506
# 5             97.213043             1.570405
# 6             98.607984             1.394941
# 7            100.000000             1.392016
#                              N3  Quantidade  Acumulativo  \
# 0                  Fato Atípico       13947        13947
# 1         Extravio de Documento        6017        19964
# 2           Extravio de Celular        2121        22085
# 3        Desaparecimento outros        1543        23628
# 4      Encontro de Desaparecido        1384        25012
# 5  Morte sem Assistência Médica         951        25963
# 6  Extravio de Placa de Veículo         948        26911
#
#    Percentual Acumulado  Percentual Absoluto
# 0             51.826391            51.826391
# 1             74.185277            22.358887
# 2             82.066813             7.881535
# 3             87.800528             5.733715
# 4             92.943406             5.142878
# 5             96.477277             3.533871
# 6            100.000000             3.522723
#                                                   N3  Quantidade  Acumulativo  \
# 0             Medida Assecuratória de Direito Futuro        8109         8109
# 1                   Cumprimento de Mandado de Prisão        3371        11480
# 2                                 Apreensão (outros)        2753        14233
# 3                  Remoção para Verificação de Óbito        1697        15930
# 4                               Apreensão de Veículo         635        16565
# 5  Proveniente de Prisão Preventiva da Unidade Po...         546        17111
# 6  Apreensão de Adolescente Infrator (Artigo 104 ...         535        17646
#
#    Percentual Acumulado  Percentual Absoluto
# 0             45.953757            45.953757
# 1             65.057237            19.103480
# 2             80.658506            15.601269
# 3             90.275417             9.616910
# 4             93.873966             3.598549
# 5             96.968151             3.094186
# 6            100.000000             3.031849
#                                N3  Quantidade  Acumulativo  \
# 0  Recuperação de Veículo Roubado        6281         6281
# 1  Recuperação de Veículo Furtado        1254         7535
#
#    Percentual Acumulado  Percentual Absoluto
# 0             83.357664            83.357664
# 1            100.000000            16.642336
#                       N3  Quantidade  Acumulativo  Percentual Acumulado  \
# 0  Estupro de Vulnerável        1109         1109             68.924798
# 1                Estupro         500         1609            100.000000
#
#    Percentual Absoluto
# 0            68.924798
# 1            31.075202
#                                                   N3  Quantidade  Acumulativo  \
# 0   Homicídio Provocado por Projétil de Arma de Fogo         977          977
# 1  Homicídio Provocado por Projétil de Arma de Fo...         644         1621
#
#    Percentual Acumulado  Percentual Absoluto
# 0             60.271437            60.271437
# 1            100.000000            39.728563

# %% [markdown]
# ## Tree Balance

# %% [markdown]
# ### Mount

# %%
import copy

# %%
tree = [
    {
        "class": "root",
        "count": 0,
        "parent": None,
        "children": [],
        "level": "N0"
    }
]
levels = ['N0', 'N1', 'N2', 'N3']

# %%
for categ in domain_hierarchy['N1'].unique():
    # Adiciona o categ ao children do pai
    tree[0]['children'].append(categ)

    # Cria o nó
    node = {
        "class": categ,
        "count": 0,
        "parent": tree[0]["class"],
        "children": [],
        "level": "N1"
    }

    # Adiciona a árvore
    tree.append(node)

# %%
for categ in domain_hierarchy['N2'].unique():
    # Adiciona o categ ao children do pai
    parent = domain_hierarchy[domain_hierarchy['N2'] == categ]['N1'].iloc[0]
    parent_index = next((index for (index, d) in enumerate(tree) if d["class"] == parent), None)
    tree[parent_index]['children'].append(categ)

    # Cria o nó
    node = {
        "class": categ,
        "count": 0,
        "parent": tree[parent_index]["class"],
        "children": [],
        "level": "N2"
    }

    # Adiciona a árvore
    tree.append(node)

# %%
for categ in domain_hierarchy['N3'].unique():
    # Adiciona o categ ao children do pai
    parent = domain_hierarchy[domain_hierarchy['N3'] == categ]['N2'].iloc[0]
    parent_index = next((index for (index, d) in enumerate(tree) if d["class"] == parent), None)
    tree[parent_index]['children'].append(categ)

    # Cria o nó
    node = {
        "class": categ,
        "count": 0,
        "parent": tree[parent_index]["class"],
        "children": [],
        "level": "N3"
    }

    # Adiciona a árvore
    tree.append(node)

# %%
def get_node(categ, level, target):
    for node in target:
        if node['class'] == categ and node['level'] == level:
            return node

    return None

# %%
def update_parents(count, node, target):
    print(f"{node['class']} - {node['count'] + count}")
    if node['class'] == 'root':
        node['count'] += count
        print("\n")
        return

    node['count'] += count
    level = levels.index(node['level']) - 1
    print(f"{node['parent']} - {levels[level]}")
    update_parents(count, get_node(node['parent'], levels[level], target), target)

# %%
values = augmented['N3'].value_counts()

total = 0

for node in tree:
    if node['level'] == 'N3':
        if node['class'] in values:
            count = values[node['class']]
            total += count
            update_parents(count, node, tree)

print(f"TOTAL: {total}")
# Out:
# Estelionato (outros) - 508900
# Estelionato - N2
# Estelionato - 508900
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 508900
# root - N0
# root - 508900
#
#
# Estelionato (outros) - Tentativa - 25742
# Estelionato - N2
# Estelionato - 534642
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 534642
# root - N0
# root - 534642
#
#
# Estelionato com Emprego de Cartão de Crédito - 15961
# Estelionato - N2
# Estelionato - 550603
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 550603
# root - N0
# root - 550603
#
#
# Roubo a Transeunte - 376907
# Roubo - N2
# Roubo - 376907
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 927510
# root - N0
# root - 927510
#
#
# Roubo de Veículo - 201397
# Roubo - N2
# Roubo - 578304
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1128907
# root - N0
# root - 1128907
#
#
# Roubo outros - 152920
# Roubo - N2
# Roubo - 731224
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1281827
# root - N0
# root - 1281827
#
#
# Roubo de Telefone Celular - 130137
# Roubo - N2
# Roubo - 861361
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1411964
# root - N0
# root - 1411964
#
#
# Roubo no Interior de Coletivo - 64440
# Roubo - N2
# Roubo - 925801
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1476404
# root - N0
# root - 1476404
#
#
# Roubo de Veículo - Moto - 40335
# Roubo - N2
# Roubo - 966136
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1516739
# root - N0
# root - 1516739
#
#
# Roubo no Interior de Veículo - 35871
# Roubo - N2
# Roubo - 1002007
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1552610
# root - N0
# root - 1552610
#
#
# Roubo de Carga - 33202
# Roubo - N2
# Roubo - 1035209
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1585812
# root - N0
# root - 1585812
#
#
# Roubo a Estabelecimento Comercial - 17314
# Roubo - N2
# Roubo - 1052523
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1603126
# root - N0
# root - 1603126
#
#
# Roubo no Interior de Estabelecimento Comercial - 9783
# Roubo - N2
# Roubo - 1062306
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1612909
# root - N0
# root - 1612909
#
#
# Furto outros - 337367
# Furto - N2
# Furto - 337367
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 1950276
# root - N0
# root - 1950276
#
#
# Furto de Telefone Celular - 149122
# Furto - N2
# Furto - 486489
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2099398
# root - N0
# root - 2099398
#
#
# Furto a Transeunte - 114355
# Furto - N2
# Furto - 600844
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2213753
# root - N0
# root - 2213753
#
#
# Furto de Veículo - 75800
# Furto - N2
# Furto - 676644
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2289553
# root - N0
# root - 2289553
#
#
# Furto no Interior de Residência - 63541
# Furto - N2
# Furto - 740185
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2353094
# root - N0
# root - 2353094
#
#
# Furto no Interior de Estabelecimento Comercial - 52868
# Furto - N2
# Furto - 793053
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2405962
# root - N0
# root - 2405962
#
#
# Furto no Interior de Coletivo - 47997
# Furto - N2
# Furto - 841050
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2453959
# root - N0
# root - 2453959
#
#
# Furto a Estabelecimento Comercial - 42639
# Furto - N2
# Furto - 883689
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2496598
# root - N0
# root - 2496598
#
#
# Furto no Interior de Veículo - 39722
# Furto - N2
# Furto - 923411
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2536320
# root - N0
# root - 2536320
#
#
# Furto de Veículo - Moto - 33440
# Furto - N2
# Furto - 956851
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2569760
# root - N0
# root - 2569760
#
#
# Furto de Bicicleta - 17494
# Furto - N2
# Furto - 974345
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2587254
# root - N0
# root - 2587254
#
#
# Furto de Placa de Veículo - 13955
# Furto - N2
# Furto - 988300
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2601209
# root - N0
# root - 2601209
#
#
# Receptação - 29101
# Receptação - N2
# Receptação - 29101
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2630310
# root - N0
# root - 2630310
#
#
# Apropriação Indébita (outros) - 14905
# Apropriação Indébita (outros) - N2
# Apropriação Indébita (outros) - 14905
# Crimes Contra Propriedade - N1
# Crimes Contra Propriedade - 2645215
# root - N0
# root - 2645215
#
#
# Homicídio Provocado por Projétil de Arma de Fogo - 18572
# Homicídio - N2
# Homicídio - 18572
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 18572
# root - N0
# root - 2663787
#
#
# Homicídio Provocado por Projétil de Arma de Fogo - Tentativa - 12237
# Homicídio - N2
# Homicídio - 30809
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 30809
# root - N0
# root - 2676024
#
#
# Estupro - 9492
# Estupro - N2
# Estupro - 9492
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 40301
# root - N0
# root - 2685516
#
#
# Estupro de Vulnerável - 21068
# Estupro - N2
# Estupro - 30560
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 61369
# root - N0
# root - 2706584
#
#
# Lesão Corporal (outros) - 200634
# Lesão Corporal - N2
# Lesão Corporal - 200634
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 262003
# root - N0
# root - 2907218
#
#
# Lesão Corporal Provocada por Socos, Tapas e Pontapés - 118258
# Lesão Corporal - N2
# Lesão Corporal - 318892
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 380261
# root - N0
# root - 3025476
#
#
# Lesão Corporal Culposa (outros) (Lei 9503/97) - 81216
# Lesão Corporal - N2
# Lesão Corporal - 400108
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 461477
# root - N0
# root - 3106692
#
#
# Lesão Corporal Culposa Provocada por Colisão de Veículo - 25397
# Lesão Corporal - N2
# Lesão Corporal - 425505
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 486874
# root - N0
# root - 3132089
#
#
# Lesão Corporal Culposa Provocada por Atropelamento - 13505
# Lesão Corporal - N2
# Lesão Corporal - 439010
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 500379
# root - N0
# root - 3145594
#
#
# Lesão Corporal Provocada por Projétil de Arma de Fogo - 9048
# Lesão Corporal - N2
# Lesão Corporal - 448058
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 509427
# root - N0
# root - 3154642
#
#
# Vias de Fato - 59479
# Lesão Corporal - N2
# Lesão Corporal - 507537
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 568906
# root - N0
# root - 3214121
#
#
# Ameaça - 355901
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 355901
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 924807
# root - N0
# root - 3570022
#
#
# Injúria (outros) - 190520
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 546421
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1115327
# root - N0
# root - 3760542
#
#
# Injúria por preconceito - 10212
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 556633
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1125539
# root - N0
# root - 3770754
#
#
# Difamação - 32538
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 589171
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1158077
# root - N0
# root - 3803292
#
#
# Calúnia - 27485
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 616656
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1185562
# root - N0
# root - 3830777
#
#
# Maus-Tratos - 9064
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 625720
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1194626
# root - N0
# root - 3839841
#
#
# Crime de Perseguição (Art 147-A CP) - 9043
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 634763
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1203669
# root - N0
# root - 3848884
#
#
# Extorsão (outros) - 14945
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - N2
# Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 649708
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1218614
# root - N0
# root - 3863829
#
#
# Descumprimento de Medidas Protetivas de Urgência - 17472
# Descumprimento de Medidas Protetivas de Urgência - N2
# Descumprimento de Medidas Protetivas de Urgência - 17472
# Crimes Contra Pessoa - N1
# Crimes Contra Pessoa - 1236086
# root - N0
# root - 3881301
#
#
# Adulteração de Sinal Identificador de Veículo Automotor - 23186
# Adulteração de Sinal Identificador de Veículo Automotor - N2
# Adulteração de Sinal Identificador de Veículo Automotor - 23186
# Crimes de Trânsito ou Meio Ambiente - N1
# Crimes de Trânsito ou Meio Ambiente - 23186
# root - N0
# root - 3904487
#
#
# Falta de Habilitação, Proibição Dirigir Veículo Automotor - 9292
# Falta de Habilitação, Proibição Dirigir Veículo Automotor - N2
# Falta de Habilitação, Proibição Dirigir Veículo Automotor - 9292
# Crimes de Trânsito ou Meio Ambiente - N1
# Crimes de Trânsito ou Meio Ambiente - 32478
# root - N0
# root - 3913779
#
#
# Sanções Penais e Administrativas ao Meio Ambiente - 8884
# Sanções Penais e Administrativas ao Meio Ambiente - N2
# Sanções Penais e Administrativas ao Meio Ambiente - 8884
# Crimes de Trânsito ou Meio Ambiente - N1
# Crimes de Trânsito ou Meio Ambiente - 41362
# root - N0
# root - 3922663
#
#
# Recuperação de Veículo Roubado - 119348
# Recuperação de Veículo - N2
# Recuperação de Veículo - 119348
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 119348
# root - N0
# root - 4042011
#
#
# Recuperação de Veículo Furtado - 23822
# Recuperação de Veículo - N2
# Recuperação de Veículo - 143170
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 143170
# root - N0
# root - 4065833
#
#
# Medida Assecuratória de Direito Futuro - 154071
# Atos Administrativos - N2
# Atos Administrativos - 154071
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 297241
# root - N0
# root - 4219904
#
#
# Cumprimento de Mandado de Prisão - 64053
# Atos Administrativos - N2
# Atos Administrativos - 218124
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 361294
# root - N0
# root - 4283957
#
#
# Apreensão (outros) - 52309
# Atos Administrativos - N2
# Atos Administrativos - 270433
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 413603
# root - N0
# root - 4336266
#
#
# Apreensão de Veículo - 12075
# Atos Administrativos - N2
# Atos Administrativos - 282508
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 425678
# root - N0
# root - 4348341
#
#
# Remoção para Verificação de Óbito - 32236
# Atos Administrativos - N2
# Atos Administrativos - 314744
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 457914
# root - N0
# root - 4380577
#
#
# Apreensão de Adolescente Infrator (Artigo 104 e 107 da Lei 8.069/90) - 10161
# Atos Administrativos - N2
# Atos Administrativos - 324905
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 468075
# root - N0
# root - 4390738
#
#
# Proveniente de Prisão Preventiva da Unidade Policial - 10366
# Atos Administrativos - N2
# Atos Administrativos - 335271
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 478441
# root - N0
# root - 4401104
#
#
# Fato Atípico - 264993
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 264993
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 743434
# root - N0
# root - 4666097
#
#
# Extravio de Documento - 114330
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 379323
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 857764
# root - N0
# root - 4780427
#
#
# Extravio de Celular - 40293
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 419616
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 898057
# root - N0
# root - 4820720
#
#
# Morte sem Assistência Médica - 18076
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 437692
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 916133
# root - N0
# root - 4838796
#
#
# Extravio de Placa de Veículo - 18008
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 455700
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 934141
# root - N0
# root - 4856804
#
#
# Encontro de Desaparecido - 26301
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 482001
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 960442
# root - N0
# root - 4883105
#
#
# Desaparecimento outros - 29313
# Registro de Um Acontecimento - N2
# Registro de Um Acontecimento - 511314
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - N1
# Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 989755
# root - N0
# root - 4912418
#
#
# Tráfico de Drogas (Lei 11.343/06) - 69335
# Tráfico de Drogas (Lei 11.343/06) - N2
# Tráfico de Drogas (Lei 11.343/06) - 69335
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 69335
# root - N0
# root - 4981753
#
#
# Porte de Droga para Consumo Próprio (Lei 11.343/06) - 64904
# Porte de Droga para Consumo Próprio (Lei 11.343/06) - N2
# Porte de Droga para Consumo Próprio (Lei 11.343/06) - 64904
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 134239
# root - N0
# root - 5046657
#
#
# Associação para Tráfico de Droga (Lei 11.343/06) - 39283
# Associação para Tráfico de Droga (Lei 11.343/06) - N2
# Associação para Tráfico de Droga (Lei 11.343/06) - 39283
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 173522
# root - N0
# root - 5085940
#
#
# Apreensão de Substância Entorpecente - 13516
# Apreensão de Substância Entorpecente - N2
# Apreensão de Substância Entorpecente - 13516
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 187038
# root - N0
# root - 5099456
#
#
# Lei de Drogas (Outros) (Lei 11.343/06) - 9422
# Lei de Drogas (Outros) (Lei 11.343/06) - N2
# Lei de Drogas (Outros) (Lei 11.343/06) - 9422
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 196460
# root - N0
# root - 5108878
#
#
# Porte Ilegal de Arma de Fogo de Uso Restrito - 8877
# Porte Ilegal de Arma de Fogo de Uso Restrito - N2
# Porte Ilegal de Arma de Fogo de Uso Restrito - 8877
# Relacionados a Drogas, Entorpecentes e Porte de Armas - N1
# Relacionados a Drogas, Entorpecentes e Porte de Armas - 205337
# root - N0
# root - 5117755
#
#
# Desacato - 14986
# Desacato - N2
# Desacato - 14986
# Resistência, Desacato ou Desobediência - N1
# Resistência, Desacato ou Desobediência - 14986
# root - N0
# root - 5132741
#
#
# Resistência - 14376
# Resistência - N2
# Resistência - 14376
# Resistência, Desacato ou Desobediência - N1
# Resistência, Desacato ou Desobediência - 29362
# root - N0
# root - 5147117
#
#
# Desobediência - 12550
# Desobediência - N2
# Desobediência - 12550
# Resistência, Desacato ou Desobediência - N1
# Resistência, Desacato ou Desobediência - 41912
# root - N0
# root - 5159667
#
#
# Resistência qualificada - 11260
# Resistência qualificada - N2
# Resistência qualificada - 11260
# Resistência, Desacato ou Desobediência - N1
# Resistência, Desacato ou Desobediência - 53172
# root - N0
# root - 5170927
#
#
# Violação de Domicílio - 22918
# Violação de Domicílio - N2
# Violação de Domicílio - 22918
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - N1
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - 22918
# root - N0
# root - 5193845
#
#
# Perturbação da Tranquilidade - 17205
# Perturbação da Tranquilidade - N2
# Perturbação da Tranquilidade - 17205
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - N1
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - 40123
# root - N0
# root - 5211050
#
#
# Exercício Arbitrário das Próprias Razões - 10537
# Exercício Arbitrário das Próprias Razões - N2
# Exercício Arbitrário das Próprias Razões - 10537
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - N1
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - 50660
# root - N0
# root - 5221587
#
#
# Dano (outros) - 37651
# Dano (outros) - N2
# Dano (outros) - 37651
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - N1
# Violação ou Perturbação ou Dano ou Exercício Arbitrário - 88311
# root - N0
# root - 5259238
#
#
# TOTAL: 5259238

# %%
def remove_node(categ, level, target):
    node = get_node(categ, level, target)
    target.remove(node)

    level = levels.index(node['level']) - 1
    
    parent = get_node(node['parent'], levels[level], target)
    parent['children'].remove(categ)

# %%
for node in tree:
    if node['count'] == 0:
        print(f"{node['class']} - {node['count']}")
        remove_node(node['class'], node['level'], tree)

# %%
def get_level_nodes(level, target):
    nodes = []
    for node in target:
        if node['level'] == level:
            nodes.append(node)

    return nodes

# %%
def tree_print(target):
    print(f"{target[0]['class']} - {target[0]['count']}")
    for child in target[0]['children']:
        node = get_node(child, 'N1', target)
        print(f"\t|- {node['class']} - {node['count']}")
        for child_2 in node['children']:
            node_2 = get_node(child_2, 'N2', target)
            print(f"\t|\t|- {node_2['class']} - {node_2['count']}")
            for child_3 in node_2['children']:
                node_3 = get_node(child_3, 'N3', target)
                print(f"\t|\t|\t|- {node_3['class']} - {node_3['count']}")

# %%
def print_level_count(level, target):
    if level in levels:
        if level != 'N0':
            index = levels.index(level)
            for node in get_level_nodes(levels[index - 1], target):
                print([get_node(child, level, target)['count'] for child in node['children']])
        else:
            print(target[0]['count'])
    else:
        print(f"Levels: {levels}")

# %%
tree_print(tree)
# Out:
# root - 5259238
# 	|- Crimes Contra Propriedade - 2645215
# 	|	|- Estelionato - 550603
# 	|	|	|- Estelionato (outros) - 508900
# 	|	|	|- Estelionato (outros) - Tentativa - 25742
# 	|	|	|- Estelionato com Emprego de Cartão de Crédito - 15961
# 	|	|- Roubo - 1062306
# 	|	|	|- Roubo a Transeunte - 376907
# 	|	|	|- Roubo de Veículo - 201397
# 	|	|	|- Roubo outros - 152920
# 	|	|	|- Roubo de Telefone Celular - 130137
# 	|	|	|- Roubo no Interior de Coletivo - 64440
# 	|	|	|- Roubo de Veículo - Moto - 40335
# 	|	|	|- Roubo no Interior de Veículo - 35871
# 	|	|	|- Roubo de Carga - 33202
# 	|	|	|- Roubo a Estabelecimento Comercial - 17314
# 	|	|	|- Roubo no Interior de Estabelecimento Comercial - 9783
# 	|	|- Furto - 988300
# 	|	|	|- Furto outros - 337367
# 	|	|	|- Furto de Telefone Celular - 149122
# 	|	|	|- Furto a Transeunte - 114355
# 	|	|	|- Furto de Veículo - 75800
# 	|	|	|- Furto no Interior de Residência - 63541
# 	|	|	|- Furto no Interior de Estabelecimento Comercial - 52868
# 	|	|	|- Furto no Interior de Coletivo - 47997
# 	|	|	|- Furto a Estabelecimento Comercial - 42639
# 	|	|	|- Furto no Interior de Veículo - 39722
# 	|	|	|- Furto de Veículo - Moto - 33440
# 	|	|	|- Furto de Bicicleta - 17494
# 	|	|	|- Furto de Placa de Veículo - 13955
# 	|	|- Receptação - 29101
# 	|	|	|- Receptação - 29101
# 	|	|- Apropriação Indébita (outros) - 14905
# 	|	|	|- Apropriação Indébita (outros) - 14905
# 	|- Crimes Contra Pessoa - 1236086
# 	|	|- Homicídio - 30809
# 	|	|	|- Homicídio Provocado por Projétil de Arma de Fogo - 18572
# 	|	|	|- Homicídio Provocado por Projétil de Arma de Fogo - Tentativa - 12237
# 	|	|- Estupro - 30560
# 	|	|	|- Estupro - 9492
# 	|	|	|- Estupro de Vulnerável - 21068
# 	|	|- Lesão Corporal - 507537
# 	|	|	|- Lesão Corporal (outros) - 200634
# 	|	|	|- Lesão Corporal Provocada por Socos, Tapas e Pontapés - 118258
# 	|	|	|- Lesão Corporal Culposa (outros) (Lei 9503/97) - 81216
# 	|	|	|- Lesão Corporal Culposa Provocada por Colisão de Veículo - 25397
# 	|	|	|- Lesão Corporal Culposa Provocada por Atropelamento - 13505
# 	|	|	|- Lesão Corporal Provocada por Projétil de Arma de Fogo - 9048
# 	|	|	|- Vias de Fato - 59479
# 	|	|- Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 649708
# 	|	|	|- Ameaça - 355901
# 	|	|	|- Injúria (outros) - 190520
# 	|	|	|- Injúria por preconceito - 10212
# 	|	|	|- Difamação - 32538
# 	|	|	|- Calúnia - 27485
# 	|	|	|- Maus-Tratos - 9064
# 	|	|	|- Crime de Perseguição (Art 147-A CP) - 9043
# 	|	|	|- Extorsão (outros) - 14945
# 	|	|- Descumprimento de Medidas Protetivas de Urgência - 17472
# 	|	|	|- Descumprimento de Medidas Protetivas de Urgência - 17472
# 	|- Crimes de Trânsito ou Meio Ambiente - 41362
# 	|	|- Adulteração de Sinal Identificador de Veículo Automotor - 23186
# 	|	|	|- Adulteração de Sinal Identificador de Veículo Automotor - 23186
# 	|	|- Falta de Habilitação, Proibição Dirigir Veículo Automotor - 9292
# 	|	|	|- Falta de Habilitação, Proibição Dirigir Veículo Automotor - 9292
# 	|	|- Sanções Penais e Administrativas ao Meio Ambiente - 8884
# 	|	|	|- Sanções Penais e Administrativas ao Meio Ambiente - 8884
# 	|- Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 989755
# 	|	|- Recuperação de Veículo - 143170
# 	|	|	|- Recuperação de Veículo Roubado - 119348
# 	|	|	|- Recuperação de Veículo Furtado - 23822
# 	|	|- Atos Administrativos - 335271
# 	|	|	|- Medida Assecuratória de Direito Futuro - 154071
# 	|	|	|- Cumprimento de Mandado de Prisão - 64053
# 	|	|	|- Apreensão (outros) - 52309
# 	|	|	|- Apreensão de Veículo - 12075
# 	|	|	|- Remoção para Verificação de Óbito - 32236
# 	|	|	|- Apreensão de Adolescente Infrator (Artigo 104 e 107 da Lei 8.069/90) - 10161
# 	|	|	|- Proveniente de Prisão Preventiva da Unidade Policial - 10366
# 	|	|- Registro de Um Acontecimento - 511314
# 	|	|	|- Fato Atípico - 264993
# 	|	|	|- Extravio de Documento - 114330
# 	|	|	|- Extravio de Celular - 40293
# 	|	|	|- Morte sem Assistência Médica - 18076
# 	|	|	|- Extravio de Placa de Veículo - 18008
# 	|	|	|- Encontro de Desaparecido - 26301
# 	|	|	|- Desaparecimento outros - 29313
# 	|- Relacionados a Drogas, Entorpecentes e Porte de Armas - 205337
# 	|	|- Tráfico de Drogas (Lei 11.343/06) - 69335
# 	|	|	|- Tráfico de Drogas (Lei 11.343/06) - 69335
# 	|	|- Porte de Droga para Consumo Próprio (Lei 11.343/06) - 64904
# 	|	|	|- Porte de Droga para Consumo Próprio (Lei 11.343/06) - 64904
# 	|	|- Associação para Tráfico de Droga (Lei 11.343/06) - 39283
# 	|	|	|- Associação para Tráfico de Droga (Lei 11.343/06) - 39283
# 	|	|- Apreensão de Substância Entorpecente - 13516
# 	|	|	|- Apreensão de Substância Entorpecente - 13516
# 	|	|- Lei de Drogas (Outros) (Lei 11.343/06) - 9422
# 	|	|	|- Lei de Drogas (Outros) (Lei 11.343/06) - 9422
# 	|	|- Porte Ilegal de Arma de Fogo de Uso Restrito - 8877
# 	|	|	|- Porte Ilegal de Arma de Fogo de Uso Restrito - 8877
# 	|- Resistência, Desacato ou Desobediência - 53172
# 	|	|- Desacato - 14986
# 	|	|	|- Desacato - 14986
# 	|	|- Resistência - 14376
# 	|	|	|- Resistência - 14376
# 	|	|- Desobediência - 12550
# 	|	|	|- Desobediência - 12550
# 	|	|- Resistência qualificada - 11260
# 	|	|	|- Resistência qualificada - 11260
# 	|- Violação ou Perturbação ou Dano ou Exercício Arbitrário - 88311
# 	|	|- Violação de Domicílio - 22918
# 	|	|	|- Violação de Domicílio - 22918
# 	|	|- Perturbação da Tranquilidade - 17205
# 	|	|	|- Perturbação da Tranquilidade - 17205
# 	|	|- Exercício Arbitrário das Próprias Razões - 10537
# 	|	|	|- Exercício Arbitrário das Próprias Razões - 10537
# 	|	|- Dano (outros) - 37651
# 	|	|	|- Dano (outros) - 37651

# %% [markdown]
# ### Balance

# %%
# Balancear Nível 3
tree_n3 = copy.deepcopy(tree)

for node in get_level_nodes('N2', tree_n3):
    minimum = min([get_node(child, 'N3', tree_n3)['count'] for child in node['children']])
    
    for child in node['children']:
        node = get_node(child, 'N3', tree_n3)
        
        diff = node['count'] - minimum
        node['count'] = minimum

        parent_N2 = get_node(node['parent'], 'N2', tree_n3)
        parent_N2['count'] -= diff
        parent_N1 = get_node(parent_N2['parent'], 'N1', tree_n3)
        parent_N1['count'] -= diff
        parent_N0 = get_node(parent_N1['parent'], 'N0', tree_n3)
        parent_N0['count'] -= diff

# %%
# Balancear o Nível 2
tree_n2 = copy.deepcopy(tree_n3)

for node_1 in get_level_nodes('N1', tree_n2):
    minimum = min([get_node(child, 'N2', tree_n2)['count'] for child in node_1['children']])

    for child_2 in node_1['children']:
        node_2 = get_node(child_2, 'N2', tree_n2)
        delta = minimum // len(node_2['children'])

        for child_3 in node_2['children']:
            node_3 = get_node(child_3, 'N3', tree_n2)
            diff = node_3['count'] - delta

            node_3['count'] -= diff
            node_2['count'] -= diff
            node_1['count'] -= diff
            tree_n2[0]['count'] -= diff

# %%
# Balancear o Nível 1
tree_n1 = copy.deepcopy(tree_n2)

minimum = min([get_node(child, 'N1', tree_n1)['count'] for child in tree[0]['children']])

for child_1 in tree[0]['children']:
    node_1 = get_node(child_1, 'N1', tree_n1)
    delta_1 = minimum // len(node_1['children'])

    for child_2 in node_1['children']:
        node_2 = get_node(child_2, 'N2', tree_n1)
        delta_2 = delta_1 // len(node_2['children'])

        for child_3 in node_2['children']:
            node_3 = get_node(child_3, 'N3', tree_n1)
            diff = node_3['count'] - delta_2

            node_3['count'] -= diff
            node_2['count'] -= diff
            node_1['count'] -= diff
            tree_n1[0]['count'] -= diff

# %%
print_level_count('N1', tree_n1)
# Out:
# [26646, 26645, 26652, 26650, 26652, 26652, 26652]

# %%
tree_print(tree_n1)
# Out:
# root - 186549
# 	|- Crimes Contra Propriedade - 26646
# 	|	|- Estelionato - 5328
# 	|	|	|- Estelionato (outros) - 1776
# 	|	|	|- Estelionato (outros) - Tentativa - 1776
# 	|	|	|- Estelionato com Emprego de Cartão de Crédito - 1776
# 	|	|- Roubo - 5330
# 	|	|	|- Roubo a Transeunte - 533
# 	|	|	|- Roubo de Veículo - 533
# 	|	|	|- Roubo outros - 533
# 	|	|	|- Roubo de Telefone Celular - 533
# 	|	|	|- Roubo no Interior de Coletivo - 533
# 	|	|	|- Roubo de Veículo - Moto - 533
# 	|	|	|- Roubo no Interior de Veículo - 533
# 	|	|	|- Roubo de Carga - 533
# 	|	|	|- Roubo a Estabelecimento Comercial - 533
# 	|	|	|- Roubo no Interior de Estabelecimento Comercial - 533
# 	|	|- Furto - 5328
# 	|	|	|- Furto outros - 444
# 	|	|	|- Furto de Telefone Celular - 444
# 	|	|	|- Furto a Transeunte - 444
# 	|	|	|- Furto de Veículo - 444
# 	|	|	|- Furto no Interior de Residência - 444
# 	|	|	|- Furto no Interior de Estabelecimento Comercial - 444
# 	|	|	|- Furto no Interior de Coletivo - 444
# 	|	|	|- Furto a Estabelecimento Comercial - 444
# 	|	|	|- Furto no Interior de Veículo - 444
# 	|	|	|- Furto de Veículo - Moto - 444
# 	|	|	|- Furto de Bicicleta - 444
# 	|	|	|- Furto de Placa de Veículo - 444
# 	|	|- Receptação - 5330
# 	|	|	|- Receptação - 5330
# 	|	|- Apropriação Indébita (outros) - 5330
# 	|	|	|- Apropriação Indébita (outros) - 5330
# 	|- Crimes Contra Pessoa - 26645
# 	|	|- Homicídio - 5330
# 	|	|	|- Homicídio Provocado por Projétil de Arma de Fogo - 2665
# 	|	|	|- Homicídio Provocado por Projétil de Arma de Fogo - Tentativa - 2665
# 	|	|- Estupro - 5330
# 	|	|	|- Estupro - 2665
# 	|	|	|- Estupro de Vulnerável - 2665
# 	|	|- Lesão Corporal - 5327
# 	|	|	|- Lesão Corporal (outros) - 761
# 	|	|	|- Lesão Corporal Provocada por Socos, Tapas e Pontapés - 761
# 	|	|	|- Lesão Corporal Culposa (outros) (Lei 9503/97) - 761
# 	|	|	|- Lesão Corporal Culposa Provocada por Colisão de Veículo - 761
# 	|	|	|- Lesão Corporal Culposa Provocada por Atropelamento - 761
# 	|	|	|- Lesão Corporal Provocada por Projétil de Arma de Fogo - 761
# 	|	|	|- Vias de Fato - 761
# 	|	|- Ameaça ou Injúria ou Perseguição ou Dano ou Extorsão - 5328
# 	|	|	|- Ameaça - 666
# 	|	|	|- Injúria (outros) - 666
# 	|	|	|- Injúria por preconceito - 666
# 	|	|	|- Difamação - 666
# 	|	|	|- Calúnia - 666
# 	|	|	|- Maus-Tratos - 666
# 	|	|	|- Crime de Perseguição (Art 147-A CP) - 666
# 	|	|	|- Extorsão (outros) - 666
# 	|	|- Descumprimento de Medidas Protetivas de Urgência - 5330
# 	|	|	|- Descumprimento de Medidas Protetivas de Urgência - 5330
# 	|- Crimes de Trânsito ou Meio Ambiente - 26652
# 	|	|- Adulteração de Sinal Identificador de Veículo Automotor - 8884
# 	|	|	|- Adulteração de Sinal Identificador de Veículo Automotor - 8884
# 	|	|- Falta de Habilitação, Proibição Dirigir Veículo Automotor - 8884
# 	|	|	|- Falta de Habilitação, Proibição Dirigir Veículo Automotor - 8884
# 	|	|- Sanções Penais e Administrativas ao Meio Ambiente - 8884
# 	|	|	|- Sanções Penais e Administrativas ao Meio Ambiente - 8884
# 	|- Recuperação de Veículo ou Atos Administrativos ou Registro de Acontecimentos - 26650
# 	|	|- Recuperação de Veículo - 8884
# 	|	|	|- Recuperação de Veículo Roubado - 4442
# 	|	|	|- Recuperação de Veículo Furtado - 4442
# 	|	|- Atos Administrativos - 8883
# 	|	|	|- Medida Assecuratória de Direito Futuro - 1269
# 	|	|	|- Cumprimento de Mandado de Prisão - 1269
# 	|	|	|- Apreensão (outros) - 1269
# 	|	|	|- Apreensão de Veículo - 1269
# 	|	|	|- Remoção para Verificação de Óbito - 1269
# 	|	|	|- Apreensão de Adolescente Infrator (Artigo 104 e 107 da Lei 8.069/90) - 1269
# 	|	|	|- Proveniente de Prisão Preventiva da Unidade Policial - 1269
# 	|	|- Registro de Um Acontecimento - 8883
# 	|	|	|- Fato Atípico - 1269
# 	|	|	|- Extravio de Documento - 1269
# 	|	|	|- Extravio de Celular - 1269
# 	|	|	|- Morte sem Assistência Médica - 1269
# 	|	|	|- Extravio de Placa de Veículo - 1269
# 	|	|	|- Encontro de Desaparecido - 1269
# 	|	|	|- Desaparecimento outros - 1269
# 	|- Relacionados a Drogas, Entorpecentes e Porte de Armas - 26652
# 	|	|- Tráfico de Drogas (Lei 11.343/06) - 4442
# 	|	|	|- Tráfico de Drogas (Lei 11.343/06) - 4442
# 	|	|- Porte de Droga para Consumo Próprio (Lei 11.343/06) - 4442
# 	|	|	|- Porte de Droga para Consumo Próprio (Lei 11.343/06) - 4442
# 	|	|- Associação para Tráfico de Droga (Lei 11.343/06) - 4442
# 	|	|	|- Associação para Tráfico de Droga (Lei 11.343/06) - 4442
# 	|	|- Apreensão de Substância Entorpecente - 4442
# 	|	|	|- Apreensão de Substância Entorpecente - 4442
# 	|	|- Lei de Drogas (Outros) (Lei 11.343/06) - 4442
# 	|	|	|- Lei de Drogas (Outros) (Lei 11.343/06) - 4442
# 	|	|- Porte Ilegal de Arma de Fogo de Uso Restrito - 4442
# 	|	|	|- Porte Ilegal de Arma de Fogo de Uso Restrito - 4442
# 	|- Resistência, Desacato ou Desobediência - 26652
# 	|	|- Desacato - 6663
# 	|	|	|- Desacato - 6663
# 	|	|- Resistência - 6663
# 	|	|	|- Resistência - 6663
# 	|	|- Desobediência - 6663
# 	|	|	|- Desobediência - 6663
# 	|	|- Resistência qualificada - 6663
# 	|	|	|- Resistência qualificada - 6663
# 	|- Violação ou Perturbação ou Dano ou Exercício Arbitrário - 26652
# 	|	|- Violação de Domicílio - 6663
# 	|	|	|- Violação de Domicílio - 6663
# 	|	|- Perturbação da Tranquilidade - 6663
# 	|	|	|- Perturbação da Tranquilidade - 6663
# 	|	|- Exercício Arbitrário das Próprias Razões - 6663
# 	|	|	|- Exercício Arbitrário das Próprias Razões - 6663
# 	|	|- Dano (outros) - 6663
# 	|	|	|- Dano (outros) - 6663

# %% [markdown]
# ## Dataset Balanced Sample

# %%
print("Total of Registers:")
print(f"N1, N2 and N3 Balanced: {tree_n1[0]['count']}")
print(f"Unbalanced: {tree[0]['count']}")
# Out:
# Total of Registers:
# N1, N2 and N3 Balanced: 186549
# Unbalanced: 5259238

# %%
def sample_data(target, dataset):
    sampled_data_list = []
    for node in get_level_nodes('N3', target):
        sampled_data_list.append(dataset[dataset['N3'] == node['class']].sample(n=node['count']))
    
    return pd.concat(sampled_data_list)

# %%
sampled_data = sample_data(tree_n1, augmented)
sampled_data.shape
# Out:
# (186549, 4)

# %%
sampled_data.columns
# Out:
# Index(['DINAMICA', 'N1', 'N2', 'N3'], dtype='object')

# %%
sampled_data.to_csv("./Datasets/06_SampledBalancedDataset.csv", index=False)

# %% [markdown]
# ## NLP Preprocessing

# %%
# !pip install spacy
# !python3 -m spacy download "pt_core_news_lg"
# Out:
# Requirement already satisfied: spacy in /home/andre/venv/lib/python3.12/site-packages (3.8.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (8.3.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: numpy>=1.19.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /home/andre/venv/lib/python3.12/site-packages (from spacy) (72.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/andre/venv/lib/python3.12/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/andre/venv/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/andre/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /home/andre/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/andre/venv/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/andre/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/andre/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/andre/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andre/venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.7.4)
# Requirement already satisfied: blis<1.2.0,>=1.1.0 in /home/andre/venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/andre/venv/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/andre/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/andre/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/andre/venv/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/andre/venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/andre/venv/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andre/venv/lib/python3.12/site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/andre/venv/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/andre/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/andre/venv/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /home/andre/venv/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/andre/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting pt-core-news-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_lg-3.8.0/pt_core_news_lg-3.8.0-py3-none-any.whl (568.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 568.2/568.2 MB 8.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_lg')

# %%
# https://medium.com/@maleeshadesilva21/preprocessing-steps-for-natural-language-processing-nlp-a-beginners-guide-d6d9bf7689c9
import re

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import spacy

# %%
# Fazendo uma cópia para manter a base sem preprocessamento
preprocessed_data = copy.deepcopy(sampled_data)

# %%
# Passando para lowercase
preprocessed_data['DINAMICA'] = sampled_data['DINAMICA'].str.lower()

# %%
# Removendo possíveis urls no texto
url_pattern = re.compile(r'https?://\S+')

def remove_url(text):
    new_text = url_pattern.sub('', text)

    # Se quiser visualizar as alterações
    # if text != new_text:
    #     print(f"{text}\n")
    #     print(f"{new_text}\n\n\n\n")
    
    return new_text

preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].apply(remove_url)

# %%
# Removendo caracteres doidos
preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].replace(to_replace=r'[^\w\s]', value='', regex=True)

# %%
# Removendo dígitos
preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].replace(to_replace=r'\d', value='', regex=True)

# %%
# Tokenização para poder remover stopwords e fazer o stemming/lemmitizing
preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].apply(word_tokenize)

# %%
# Removendo stopwords
# https://www-geeksforgeeks-org.translate.goog/removing-stop-words-nltk-python/?_x_tr_sl=en&_x_tr_tl=pt&_x_tr_hl=pt&_x_tr_pto=tc

# nltk.download('stopwords')
stop = set(stopwords.words('portuguese'))

def remove_stopwords(text):
    new_text = [word for word in text if word not in stop]

    # Se quiser visualizar as alterações
    # if text != new_text:
    #     print(f"{text}\n\n")
    #     print([word for word in data['DINAMICA'][0] if word not in stop])
    #     print("\n\n\n\n")

    return new_text

preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].apply(remove_stopwords)

# %%
# Stemming ou Lemmatizing
# https://www.alura.com.br/artigos/lemmatization-vs-stemming-quando-usar-cada-uma?srsltid=AfmBOorxWm2lE7ueBG612G7amCSTLy06GjdyjeN6jPhlIGtLoMBdRf3c
nlp = spacy.load('pt_core_news_lg')

def lemmatizer(text):
    new_text = [token.lemma_ for token in nlp(' '.join(text))]
    return new_text
    
preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].apply(lemmatizer)

# %%
# Desfazer a tokenização pq o E5 vai fazer a dele de novo
def detokenizer(text):
    new_text = ' '.join(text)
    return new_text
    
preprocessed_data['DINAMICA'] = preprocessed_data['DINAMICA'].apply(detokenizer)

# %%
preprocessed_data.to_csv("./Datasets/07_PreprocBalancedDataset.csv", index=False)

# %% [markdown]
# ## Numerical Vectors

# %%
from sentence_transformers import SentenceTransformer
from xgboost import XGBClassifier
from tqdm import tqdm

import math

tqdm.pandas()
# Out:
# /home/andre/venv/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# 2025-03-05 13:52:57.203630: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-05 13:52:57.958542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741193578.253340   10212 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741193578.343256   10212 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-05 13:52:59.128147: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = SentenceTransformer('intfloat/multilingual-e5-large-instruct')

# %%
columns = [f"Embedding_{i}" for i in range(1024)]

def generate_embedding(row):
    embedding = model.encode(row['DINAMICA'], convert_to_tensor=False, normalize_embeddings=True)
    return pd.concat([row, pd.Series(embedding, index=columns)])

# %%
# start_index é o número inicial do próximo arquivo. Por exemplo 000 ou 001 ou 002
# mas coloca só o número  como 0 ou 1 ou 2
def embed(dataset, file_number, slice_size, name_reductor, start_index=0, base_type='Raw'):
    SLICE = slice_size
    REDUCTOR = name_reductor
    
    for i in range(start_index, math.ceil(len(dataset) / SLICE)):
        start = i * SLICE
        start_name = int((i * SLICE) / REDUCTOR)
        end = (i + 1) * SLICE
        end_name = int(end  / REDUCTOR)
        index = "{:03d}".format(i)

        file_name = f"{file_number}_{index}_{base_type}_embeddings_{start_name}_{end_name}.csv"

        print(f"Index {index}: Start Row: {start} - End Row: {end}")
        print(f"File Name: {file_name}")

        dataset.iloc[start:end,:].progress_apply(generate_embedding, axis=1).to_csv(f"./Datasets/{file_name}", index=False)

# %% [markdown]
# ### Train Datasets

# %%
embed(sampled_data, '08', 50000, 1000, start_index=0, base_type='Raw')
# Out:
# Index 000: Start Row: 0 - End Row: 50000
# File Name: 08_000_Raw_embeddings_0_50.csv
# 100%|███████████████████████████████| 50000/50000 [34:58<00:00, 23.83it/s]
# Index 001: Start Row: 50000 - End Row: 100000
# File Name: 08_001_Raw_embeddings_50_100.csv
# 100%|███████████████████████████████| 50000/50000 [28:28<00:00, 29.27it/s]
# Index 002: Start Row: 100000 - End Row: 150000
# File Name: 08_002_Raw_embeddings_100_150.csv
# 100%|███████████████████████████████| 50000/50000 [36:57<00:00, 22.54it/s]
# Index 003: Start Row: 150000 - End Row: 200000
# File Name: 08_003_Raw_embeddings_150_200.csv
# 100%|███████████████████████████████| 36549/36549 [26:25<00:00, 23.06it/s]

# %%
embed(preprocessed_data, '09', 50000, 1000, start_index=0, base_type='Preproc')
# Out:
# Index 000: Start Row: 0 - End Row: 50000
# File Name: 09_000_Preproc_embeddings_0_50.csv
# 100%|███████████████████████████████| 50000/50000 [21:40<00:00, 38.46it/s]
# Index 001: Start Row: 50000 - End Row: 100000
# File Name: 09_001_Preproc_embeddings_50_100.csv
# 100%|███████████████████████████████| 50000/50000 [18:32<00:00, 44.93it/s]
# Index 002: Start Row: 100000 - End Row: 150000
# File Name: 09_002_Preproc_embeddings_100_150.csv
# 100%|███████████████████████████████| 50000/50000 [24:07<00:00, 34.53it/s]
# Index 003: Start Row: 150000 - End Row: 200000
# File Name: 09_003_Preproc_embeddings_150_200.csv
# 100%|███████████████████████████████| 36549/36549 [16:43<00:00, 36.41it/s]

# %% [markdown]
# ### Never-seen-before Dataset

# %%
embed(test_data, '12', 50000, 1000, start_index=0, base_type='NeverSeen')
# Out:
# Index 000: Start Row: 0 - End Row: 50000
# File Name: 12_000_NeverSeen_embeddings_0_50.csv
# 100%|█████████████████████████████████████| 50000/50000 [31:19<00:00, 26.60it/s]
# Index 001: Start Row: 50000 - End Row: 100000
# File Name: 12_001_NeverSeen_embeddings_50_100.csv
# 100%|█████████████████████████████████████| 50000/50000 [30:01<00:00, 27.76it/s]
# Index 002: Start Row: 100000 - End Row: 150000
# File Name: 12_002_NeverSeen_embeddings_100_150.csv
# 100%|█████████████████████████████████████| 50000/50000 [30:03<00:00, 27.72it/s]
# Index 003: Start Row: 150000 - End Row: 200000
# File Name: 12_003_NeverSeen_embeddings_150_200.csv
# 100%|█████████████████████████████████████| 50000/50000 [29:29<00:00, 28.26it/s]
# Index 004: Start Row: 200000 - End Row: 250000
# File Name: 12_004_NeverSeen_embeddings_200_250.csv
# 100%|█████████████████████████████████████| 50000/50000 [29:43<00:00, 28.04it/s]
# Index 005: Start Row: 250000 - End Row: 300000
# File Name: 12_005_NeverSeen_embeddings_250_300.csv
# 100%|█████████████████████████████████████| 26803/26803 [15:51<00:00, 28.16it/s]

# %% [markdown]
# ## Dataset Anonymization

# %%
import glob

# %%
def read_and_concat(dir_path):
    dir_path = dir_path + '*.csv'
    filelist = glob.glob(dir_path)
    dataframes = []
    
    for filename in sorted(filelist): 
        print (str(filename))
        dataframes.append(pd.read_csv(filename))

    data = pd.concat(dataframes)
    data = data.drop(columns=['DINAMICA'])
    
    return data

# %% [markdown]
# ### Train Datasets

# %%
raw = read_and_concat("./Datasets/08")
raw.head()
# Out:
# ./Datasets/08_000_Raw_embeddings_0_50.csv
# ./Datasets/08_001_Raw_embeddings_50_100.csv
# ./Datasets/08_002_Raw_embeddings_100_150.csv
# ./Datasets/08_003_Raw_embeddings_150_200.csv
#                           N1           N2                    N3  Embedding_0  \
# 0  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.012348
# 1  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.024326
# 2  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.003191
# 3  Crimes Contra Propriedade  Estelionato  Estelionato (outros)    -0.010253
# 4  Crimes Contra Propriedade  Estelionato  Estelionato (outros)    -0.003626
#
#    Embedding_1  Embedding_2  Embedding_3  Embedding_4  Embedding_5  \
# 0     0.040149    -0.015960    -0.058446     0.001246    -0.016166
# 1     0.026108    -0.019716    -0.079539     0.005686    -0.010184
# 2     0.024324    -0.027929    -0.080219    -0.004631    -0.020091
# 3     0.015941    -0.000855    -0.071614     0.007259    -0.033037
# 4     0.022467    -0.010117    -0.080650    -0.008691    -0.027933
#
#    Embedding_6  ...  Embedding_1014  Embedding_1015  Embedding_1016  \
# 0    -0.041804  ...       -0.046289       -0.005526        0.031592
# 1    -0.061117  ...       -0.029137       -0.014215        0.021615
# 2    -0.040208  ...       -0.020344       -0.033554        0.017295
# 3    -0.041098  ...       -0.039573       -0.013523        0.041449
# 4    -0.043706  ...       -0.028230       -0.021014        0.034443
#
#    Embedding_1017  Embedding_1018  Embedding_1019  Embedding_1020  \
# 0       -0.010259       -0.003605        0.007059        0.004279
# 1       -0.012493       -0.025498        0.018614        0.016457
# 2       -0.019509       -0.003888        0.008601        0.015066
# 3       -0.026685        0.007844        0.009810        0.026530
# 4       -0.020132       -0.003016        0.012413        0.025609
#
#    Embedding_1021  Embedding_1022  Embedding_1023
# 0       -0.009982       -0.024476       -0.012056
# 1       -0.018251       -0.061449        0.007135
# 2       -0.017995       -0.046333       -0.000415
# 3       -0.017604       -0.048347       -0.003660
# 4       -0.026614       -0.043004       -0.008974
#
# [5 rows x 1027 columns]

# %%
preproc = read_and_concat("./Datasets/09")
preproc.head()
# Out:
# ./Datasets/09_000_Preproc_embeddings_0_50.csv
# ./Datasets/09_001_Preproc_embeddings_50_100.csv
# ./Datasets/09_002_Preproc_embeddings_100_150.csv
# ./Datasets/09_003_Preproc_embeddings_150_200.csv
#                           N1           N2                    N3  Embedding_0  \
# 0  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.024872
# 1  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.012854
# 2  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.012884
# 3  Crimes Contra Propriedade  Estelionato  Estelionato (outros)    -0.000294
# 4  Crimes Contra Propriedade  Estelionato  Estelionato (outros)     0.001136
#
#    Embedding_1  Embedding_2  Embedding_3  Embedding_4  Embedding_5  \
# 0     0.012243    -0.015403    -0.055005     0.002113    -0.019193
# 1     0.014167    -0.010214    -0.067450     0.024207    -0.010210
# 2     0.025145    -0.028492    -0.078217     0.005706    -0.017330
# 3    -0.001026    -0.005048    -0.064348     0.018758    -0.027287
# 4     0.006518    -0.011555    -0.057545     0.005468    -0.021173
#
#    Embedding_6  ...  Embedding_1014  Embedding_1015  Embedding_1016  \
# 0    -0.049924  ...       -0.051954       -0.015725        0.019631
# 1    -0.053360  ...       -0.040303       -0.039631        0.016250
# 2    -0.048490  ...       -0.013685       -0.044063        0.022132
# 3    -0.036498  ...       -0.033500       -0.021881        0.032972
# 4    -0.034731  ...       -0.034211       -0.038460        0.020680
#
#    Embedding_1017  Embedding_1018  Embedding_1019  Embedding_1020  \
# 0       -0.033880        0.005812        0.001146        0.008117
# 1       -0.021304       -0.034026        0.008419        0.022837
# 2       -0.034129       -0.003693        0.015664        0.034866
# 3       -0.035627        0.004569        0.003972        0.013301
# 4       -0.040388        0.000890        0.004069        0.023184
#
#    Embedding_1021  Embedding_1022  Embedding_1023
# 0       -0.031364       -0.035207        0.000757
# 1       -0.035077       -0.051346        0.008260
# 2       -0.018603       -0.043413       -0.004023
# 3       -0.025269       -0.060999       -0.002277
# 4       -0.040071       -0.053121       -0.000497
#
# [5 rows x 1027 columns]

# %%
raw.to_csv("./Datasets/10_RawTrainANON.csv", index=False)
preproc.to_csv("./Datasets/11_PreprocTrainANON.csv", index=False)

# %% [markdown]
# ### Never-seen-before Dataset

# %%
import pandas as pd

# %%
never_seen = read_and_concat("./Datasets/12")
never_seen.head()
# Out:
# ./Datasets/12_001_NeverSeen_embeddings_0_50.csv
# ./Datasets/12_002_NeverSeen_embeddings_50_100.csv
# ./Datasets/12_003_NeverSeen_embeddings_100_150.csv
# ./Datasets/12_004_NeverSeen_embeddings_150_200.csv
# ./Datasets/12_005_NeverSeen_embeddings_200_250.csv
# ./Datasets/12_006_NeverSeen_embeddings_250_300.csv
#                                                   N1  \
# 0                          Crimes Contra Propriedade
# 1  Relacionados a Drogas, Entorpecentes e Porte d...
# 2                          Crimes Contra Propriedade
# 3                               Crimes Contra Pessoa
# 4                               Crimes Contra Pessoa
#
#                                   N2                                 N3  \
# 0                              Roubo                       Roubo outros
# 1  Tráfico de Drogas (Lei 11.343/06)  Tráfico de Drogas (Lei 11.343/06)
# 2                              Furto                   Furto de Veículo
# 3                     Lesão Corporal            Lesão Corporal (outros)
# 4                     Lesão Corporal            Lesão Corporal (outros)
#
#    Embedding_0  Embedding_1  Embedding_2  Embedding_3  Embedding_4  \
# 0     0.034882     0.063790    -0.015701    -0.063728     0.000136
# 1     0.019780     0.044434    -0.027141    -0.051432    -0.002872
# 2     0.017073     0.048304     0.003193    -0.063010     0.004186
# 3     0.009665     0.037534    -0.020050    -0.075351     0.010530
# 4     0.004789     0.038305    -0.024471    -0.070292     0.025082
#
#    Embedding_5  Embedding_6  ...  Embedding_1014  Embedding_1015  \
# 0    -0.022096    -0.070146  ...       -0.023706       -0.027641
# 1    -0.033528    -0.040532  ...       -0.046990       -0.032765
# 2    -0.018590    -0.038764  ...       -0.034150       -0.036247
# 3    -0.022181    -0.044396  ...       -0.023913       -0.020958
# 4    -0.007041    -0.044010  ...       -0.020124       -0.023722
#
#    Embedding_1016  Embedding_1017  Embedding_1018  Embedding_1019  \
# 0        0.029843       -0.006920       -0.006165        0.030821
# 1        0.045602       -0.000821        0.002429        0.036821
# 2        0.015059       -0.000946        0.019414        0.044906
# 3        0.014824       -0.004242       -0.004369        0.033687
# 4        0.025267       -0.015664        0.004516        0.008269
#
#    Embedding_1020  Embedding_1021  Embedding_1022  Embedding_1023
# 0        0.023737       -0.014206       -0.029136        0.018848
# 1        0.032598        0.000609       -0.057442        0.009181
# 2        0.031639       -0.019450       -0.067131        0.011651
# 3        0.028239       -0.001719       -0.027303        0.018591
# 4        0.013570       -0.010425       -0.046632        0.004869
#
# [5 rows x 1027 columns]

# %%
never_seen.to_csv("./Datasets/13_NeverSeenANON.csv", index=False)
